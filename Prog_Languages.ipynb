# %% [markdown]
# ## This is data of Programming Languages on Stackoverflow

# %% [markdown]
# ## Import Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv('QueryResults.csv', names=['DATE', 'TAG', 'POSTS'], header=0)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# **Challenge**: Read the .csv file and store it in a Pandas dataframe

# %%
df
# Out:
#                      DATE         TAG  POSTS
# 0     2008-07-01 00:00:00          c#      3
# 1     2008-08-01 00:00:00    assembly      8
# 2     2008-08-01 00:00:00  javascript    162
# 3     2008-08-01 00:00:00           c     85
# 4     2008-08-01 00:00:00      python    124
# ...                   ...         ...    ...
# 1986  2020-07-01 00:00:00           r   5694
# 1987  2020-07-01 00:00:00          go    743
# 1988  2020-07-01 00:00:00        ruby    775
# 1989  2020-07-01 00:00:00        perl    182
# 1990  2020-07-01 00:00:00       swift   3607
#
# [1991 rows x 3 columns]

# %% [markdown]
# **Challenge**: Examine the first 5 rows and the last 5 rows of the of the dataframe

# %%
df.head(5)
# Out:
#                   DATE         TAG  POSTS
# 0  2008-07-01 00:00:00          c#      3
# 1  2008-08-01 00:00:00    assembly      8
# 2  2008-08-01 00:00:00  javascript    162
# 3  2008-08-01 00:00:00           c     85
# 4  2008-08-01 00:00:00      python    124

# %%
df.tail(5)
# Out:
#                      DATE    TAG  POSTS
# 1986  2020-07-01 00:00:00      r   5694
# 1987  2020-07-01 00:00:00     go    743
# 1988  2020-07-01 00:00:00   ruby    775
# 1989  2020-07-01 00:00:00   perl    182
# 1990  2020-07-01 00:00:00  swift   3607

# %% [markdown]
# **Challenge:** Check how many rows and how many columns there are.
# What are the dimensions of the dataframe?

# %%
#shows shape and size
df.shape
# Out:
# (1991, 3)

# %% [markdown]
# **Challenge**: Count the number of entries in each column of the dataframe

# %%
df.count()
# Out:
# DATE     1991
# TAG      1991
# POSTS    1991
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1991 entries, 0 to 1990
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    1991 non-null   str
#  1   TAG     1991 non-null   str
#  2   POSTS   1991 non-null   int64
# dtypes: int64(1), str(2)
# memory usage: 46.8 KB

# %%
df.describe()
# Out:
#               POSTS
# count   1991.000000
# mean    5069.401306
# std     6065.055196
# min        1.000000
# 25%      426.500000
# 50%     2472.000000
# 75%     8163.000000
# max    34478.000000

# %% [markdown]
# **Challenge**: Calculate the total number of post per language.
# Which Programming language has had the highest total number of posts of all time?

# %%
df.groupby("TAG").sum()#.sort_values(by="TagName")

#df.sort_values(by='POSTS', ascending=False).head()
# Out:
#                                                          DATE    POSTS
# TAG
# assembly    2008-08-01 00:00:002008-09-01 00:00:002008-10-...    34852
# c           2008-08-01 00:00:002008-09-01 00:00:002008-10-...   336042
# c#          2008-07-01 00:00:002008-08-01 00:00:002008-09-...  1423530
# c++         2008-08-01 00:00:002008-09-01 00:00:002008-10-...   684210
# delphi      2008-08-01 00:00:002008-09-01 00:00:002008-10-...    46212
# go          2009-11-01 00:00:002009-12-01 00:00:002010-01-...    47499
# java        2008-08-01 00:00:002008-09-01 00:00:002008-10-...  1696403
# javascript  2008-08-01 00:00:002008-09-01 00:00:002008-10-...  2056510
# perl        2008-08-01 00:00:002008-09-01 00:00:002008-10-...    65286
# php         2008-08-01 00:00:002008-09-01 00:00:002008-10-...  1361988
# python      2008-08-01 00:00:002008-09-01 00:00:002008-10-...  1496210
# r           2008-09-01 00:00:002008-11-01 00:00:002008-12-...   356799
# ...

# %% [markdown]
# Some languages are older (e.g., C) and other languages are newer (e.g., Swift). The dataset starts in September 2008.
#
# **Challenge**: How many months of data exist per language? Which language had the fewest months with an entry?

# %%
df.groupby("TAG").count()
# Out:
#             DATE  POSTS
# TAG
# assembly     144    144
# c            144    144
# c#           145    145
# c++          144    144
# delphi       144    144
# go           129    129
# java         144    144
# javascript   144    144
# perl         144    144
# php          144    144
# python       144    144
# r            142    142
# ruby         144    144
# swift        135    135

# %% [markdown]
# ## Data Cleaning
#
# Let's fix the date format to make it more readable. We need to use Pandas to change format from a string of "2008-07-01 00:00:00" to a datetime object with the format of "2008-07-01"

# %%
type(df['DATE'][1])
# Out:
# str

# %%
#convert the entire column
df.DATE = pd.to_datetime(df.DATE)
df.head()
# Out:
#         DATE         TAG  POSTS
# 0 2008-07-01          c#      3
# 1 2008-08-01    assembly      8
# 2 2008-08-01  javascript    162
# 3 2008-08-01           c     85
# 4 2008-08-01      python    124

# %% [markdown]
# ## Data Manipulation

# %%
test_df = pd.DataFrame({'Age': ['Young', 'Young', 'Young', 'Young', 'Old', 'Old', 'Old', 'Old'],
                        'Actor': ['Jack', 'Arnold', 'Keanu', 'Sylvester', 'Jack', 'Arnold', 'Keanu', 'Sylvester'],
                        'Power': [100, 80, 25, 50, 99, 75, 5, 30]})
test_df
# Out:
#      Age      Actor  Power
# 0  Young       Jack    100
# 1  Young     Arnold     80
# 2  Young      Keanu     25
# 3  Young  Sylvester     50
# 4    Old       Jack     99
# 5    Old     Arnold     75
# 6    Old      Keanu      5
# 7    Old  Sylvester     30

# %%
pivoted_df = test_df.pivot(index='Age', columns='Actor', values='Power')
pivoted_df
# Out:
# Actor  Arnold  Jack  Keanu  Sylvester
# Age
# Old        75    99      5         30
# Young      80   100     25         50

# %%
#df2 = df.copy()
#df2
df2_pivot = df2.pivot(index='DATE', columns='TAG', values='POSTS')
df2_pivot
# Out:
# TAG         assembly       c       c#     c++  delphi     go     java  \
# DATE
# 2008-07-01       NaN     NaN      3.0     NaN     NaN    NaN      NaN
# 2008-08-01       8.0    85.0    511.0   164.0    14.0    NaN    222.0
# 2008-09-01      28.0   321.0   1649.0   755.0   105.0    NaN   1137.0
# 2008-10-01      15.0   303.0   1989.0   811.0   112.0    NaN   1153.0
# 2008-11-01      17.0   259.0   1730.0   735.0   141.0    NaN    958.0
# ...              ...     ...      ...     ...     ...    ...      ...
# 2020-03-01     317.0  2670.0   8954.0  5107.0   181.0  719.0  13253.0
# 2020-04-01     406.0  3472.0  10042.0  6820.0   250.0  887.0  15377.0
# 2020-05-01     386.0  3602.0   9923.0  7063.0   221.0  826.0  14711.0
# 2020-06-01     363.0  2757.0   9064.0  6161.0   214.0  765.0  13015.0
# 2020-07-01     298.0  2294.0   9145.0  5756.0   212.0  743.0  12723.0
#
# TAG         javascript   perl     php   python       r   ruby   swift
# DATE
# ...

# %% [markdown]
# **Challenge**: What are the dimensions of our new dataframe? How many rows and columns does it have? Print out the column names and print out the first 5 rows of the dataframe.

# %%
df2_pivot.shape
# Out:
# (145, 14)

# %%
df2_pivot.ndim
# Out:
# 2

# %%
df2_pivot.columns
# Out:
# Index(['assembly', 'c', 'c#', 'c++', 'delphi', 'go', 'java', 'javascript',
#        'perl', 'php', 'python', 'r', 'ruby', 'swift'],
#       dtype='str', name='TAG')

# %%
df.head(5)
# Out:
#         DATE         TAG  POSTS
# 0 2008-07-01          c#      3
# 1 2008-08-01    assembly      8
# 2 2008-08-01  javascript    162
# 3 2008-08-01           c     85
# 4 2008-08-01      python    124

# %%
df2_pivot.count()
# Out:
# TAG
# assembly      144
# c             144
# c#            145
# c++           144
# delphi        144
# go            129
# java          144
# javascript    144
# perl          144
# php           144
# python        144
# r             142
# ruby          144
# swift         135
# dtype: int64

# %% [markdown]
# **Challenge**: Count the number of entries per programming language. Why might the number of entries be different?

# %% [markdown]
# ## Data Visualisaton with with Matplotlib

# %% [markdown]
# **Challenge**: Use the [matplotlib documentation](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot) to plot a single programming language (e.g., java) on a chart.

# %%
df2_pivot.head()
# Out:
# TAG         assembly      c      c#    c++  delphi  go    java  javascript  \
# DATE
# 2008-07-01       NaN    NaN     3.0    NaN     NaN NaN     NaN         NaN
# 2008-08-01       8.0   85.0   511.0  164.0    14.0 NaN   222.0       162.0
# 2008-09-01      28.0  321.0  1649.0  755.0   105.0 NaN  1137.0       640.0
# 2008-10-01      15.0  303.0  1989.0  811.0   112.0 NaN  1153.0       725.0
# 2008-11-01      17.0  259.0  1730.0  735.0   141.0 NaN   958.0       579.0
#
# TAG          perl    php  python    r   ruby  swift
# DATE
# 2008-07-01    NaN    NaN     NaN  NaN    NaN    NaN
# 2008-08-01   28.0  161.0   124.0  NaN   73.0    NaN
# 2008-09-01  131.0  482.0   542.0  6.0  290.0    NaN
# 2008-10-01  127.0  617.0   510.0  NaN  249.0    NaN
# 2008-11-01   97.0  504.0   452.0  1.0  160.0    NaN

# %%
plt.plot(df2_pivot.index, df2_pivot.java)

# %%
plt.figure(figsize=(16,10)) 
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.ylim(0, 35000)
plt.plot(df2_pivot.index, df2_pivot.java)

# %% [markdown]
# **Challenge**: Show two line (e.g. for Java and Python) on the same chart.

# %%
plt.figure(figsize=(16,10)) 
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.ylim(0, 35000)
plt.plot(df2_pivot.index, df2_pivot.java)
plt.plot(df2_pivot.index, df2_pivot.python)

# %%
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.ylim(0, 35000)

#for loop that plots all the different languages simply
for column in df2_pivot.columns:
    plt.plot(df2_pivot.index, df2_pivot[column], 
             linewidth=3, label=df2_pivot[column].name)
 
plt.legend(fontsize=16)

# %% [markdown]
# # Smoothing out Time Series Data
#
# Time series data can be quite noisy, with a lot of up and down spikes. To better see a trend we can plot an average of, say 6 or 12 observations. This is called the rolling mean. We calculate the average in a window of time and move it forward by one overservation. Pandas has two handy methods already built in to work this out: [rolling()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rolling.html) and [mean()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.core.window.rolling.Rolling.mean.html).

# %%
# The window is number of observations that are averaged
roll_df22 = df2_pivot.rolling(window=6).mean()

plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.ylim(0, 35000)

#for loop that plots all the different languages simply
for column in roll_df22.columns:
    plt.plot(roll_df22.index, roll_df22[column], 
             linewidth=3, label=roll_df22[column].name)
 
plt.legend(fontsize=16)
